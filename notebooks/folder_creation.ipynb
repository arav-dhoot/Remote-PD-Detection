# %%
import os

# %%
folder =

# %%
for subfolder in os.listdir(folder):
    for subsubfolder in os.listdir(os.path.join(folder, subfolder)):
        os.makedirs(os.path.join(folder, subfolder, subsubfolder, 'Front'), exist_ok=True)
        os.makedirs(os.path.join(folder, subfolder, subsubfolder, 'Back'), exist_ok=True)
        os.makedirs(os.path.join(folder, subfolder, subsubfolder, 'Sideway'), exist_ok=True)
        os.makedirs(os.path.join(folder, subfolder, subsubfolder, 'Turn'), exist_ok=True)
